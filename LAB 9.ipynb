# %%
#NAME: Shaza Adelina Binti Khairullah
#ID:SN0107857
#LAB 9 TOPIC MODELLING

# %%
import pandas as pd
import pandas as pd

df = pd.read_csv('npr.csv')
print(df.head())

from gensim import corpora
from gensim.models import LdaModel
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# sample small data (so you SEE output fast)
documents = [
    "Biden announces new virus plan",
    "Government discusses health policy",
    "Nadal wins tennis match",
    "Federer plays in US Open"
]

# preprocessing
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

def preprocess(text):
    tokens = word_tokenize(text.lower())
    tokens = [t for t in tokens if t.isalnum()]
    tokens = [t for t in tokens if t not in stop_words]
    tokens = [lemmatizer.lemmatize(t) for t in tokens]
    return tokens

processed_docs = [preprocess(doc) for doc in documents]

# dictionary + corpus
dictionary = corpora.Dictionary(processed_docs)
corpus = [dictionary.doc2bow(doc) for doc in processed_docs]

# LDA model
lda_model = LdaModel(corpus, num_topics=2, id2word=dictionary, passes=10)

# 🔥 PRINT OUTPUT
print("=== TOPICS ===")
print(lda_model.print_topics())

print("\n=== DOCUMENT TOPICS ===")
for i, doc in enumerate(corpus):
    print(f"Doc {i}:", lda_model.get_document_topics(doc))
# Out:
#                                              Article
# 0  In the Washington of 2016, even when the polic...
# 1    Donald Trump has used Twitter  —   his prefe...
# 2    Donald Trump is unabashedly praising Russian...
# 3  Updated at 2:50 p. m. ET, Russian President Vl...
# 4  From photography, illustration and video, to d...
# === TOPICS ===
# [(0, '0.085*"plan" + 0.085*"announces" + 0.085*"new" + 0.085*"biden" + 0.085*"virus" + 0.085*"government" + 0.085*"discusses" + 0.085*"health" + 0.085*"policy" + 0.029*"u"'), (1, '0.090*"match" + 0.090*"tennis" + 0.090*"nadal" + 0.090*"win" + 0.090*"federer" + 0.090*"open" + 0.090*"play" + 0.090*"u" + 0.031*"policy" + 0.031*"health"')]
#
# === DOCUMENT TOPICS ===
# Doc 0: [(0, np.float32(0.91275376)), (1, np.float32(0.08724623))]
# Doc 1: [(0, np.float32(0.89525783)), (1, np.float32(0.10474218))]
# Doc 2: [(0, np.float32(0.10412426)), (1, np.float32(0.89587575))]
# Doc 3: [(0, np.float32(0.1041777)), (1, np.float32(0.89582235))]
